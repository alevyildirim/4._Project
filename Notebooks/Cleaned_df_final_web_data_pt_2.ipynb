# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Exploring the data

# %%
file_path = r'C:\Users\ALEV PC\Desktop\Project\Data\Raw data\df_final_web_data_pt_2.txt'
df = pd.read_csv(file_path)
df
# Out:
#         client_id             visitor_id                      visit_id  \
# 0          763412  601952081_10457207388  397475557_40440946728_419634
# 1         6019349  442094451_91531546617  154620534_35331068705_522317
# 2         6019349  442094451_91531546617  154620534_35331068705_522317
# 3         6019349  442094451_91531546617  154620534_35331068705_522317
# 4         6019349  442094451_91531546617  154620534_35331068705_522317
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0           confirm  2017-06-06 08:56:00
# ...

# %%
print(df.isnull().sum())
# Out:
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64

# %%
print("Unique values in 'process_step' column:", df['process_step'].unique())
# Out:
# Unique values in 'process_step' column: ['confirm' 'step_3' 'step_2' 'step_1' 'start']

# %% [markdown]
# # Data cleaning

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#         client_id             visitor_id                      visit_id  \
# 0          763412  601952081_10457207388  397475557_40440946728_419634
# 1         6019349  442094451_91531546617  154620534_35331068705_522317
# 2         6019349  442094451_91531546617  154620534_35331068705_522317
# 3         6019349  442094451_91531546617  154620534_35331068705_522317
# 4         6019349  442094451_91531546617  154620534_35331068705_522317
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0           confirm  2017-06-06 08:56:00
# ...

# %%
import pandas as pd

# Sample DataFrame with 'process_step' column
data = {'process_step': ['confirm', 'step_3', 'step_2', 'step_1', 'start']}
df = pd.DataFrame(data)

# Create dummy variables for 'process_step' column
dummies = pd.get_dummies(df['process_step'])

# Concatenate dummy variables with original DataFrame
df = pd.concat([df, dummies], axis=1)

# Drop the original 'process_step' column
df.drop('process_step', axis=1, inplace=True)

print(df)
# Out:
#    confirm  start  step_1  step_2  step_3
# 0     True  False   False   False   False
# 1    False  False   False   False    True
# 2    False  False   False    True   False
# 3    False  False    True   False   False
# 4    False   True   False   False   False
